# %%
# Get AlexeyAB Darknet, dataset, and config files
# %%bash
git clone https://github.com/AlexeyAB/darknet.git
cd /content/darknet
wget https://students.washington.edu/bhimar/eval.tar.gz
rm -rf data
tar -xzf eval.tar.gz
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.
# --2020-12-19 05:14:57--  https://students.washington.edu/bhimar/eval.tar.gz
# Resolving students.washington.edu (students.washington.edu)... 128.208.181.36, 128.95.242.206
# Connecting to students.washington.edu (students.washington.edu)|128.208.181.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341578391 (326M) [application/x-gzip]
# Saving to: ‘eval.tar.gz.1’
#
#      0K .......... .......... .......... .......... ..........  0%  368K 15m6s
#     50K .......... .......... .......... .......... ..........  0%  760K 11m12s
#    100K .......... .......... .......... .......... ..........  0%  757K 9m55s
#    150K .......... .......... .......... .......... ..........  0% 11.7M 7m33s
#    200K .......... .......... .......... .......... ..........  0%  780K 7m28s
#    250K .......... .......... .......... .......... ..........  0% 16.0M 6m17s
# ...

# %% [markdown]
# # Modify Makefile
# Set GPU, CUDANN, and OPENCV to 1

# %%
# make and run mAP evaluation
# %%bash
cd /content/darknet
make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ...

# %%
# run mAP evaluation
# %%bash
cd /content/darknet
./darknet detector map data/frieburg.data yolov3_custom_train.cfg yolov3_custom_train_6000.weights
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#
#  seen 64, trained: 384 K-images (6 Kilo-batches_64)
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
#
#  detections_count = 5351, unique_truth_count = 2261
# class_id = 0, name = beans, ap = 84.26%   	 (TP = 33, FP = 9)
# class_id = 1, name = cake, ap = 84.02%   	 (TP = 31, FP = 6)
# class_id = 2, name = candy, ap = 75.92%   	 (TP = 74, FP = 8)
# class_id = 3, name = cereal, ap = 90.44%   	 (TP = 67, FP = 12)
# class_id = 4, name = chips, ap = 79.68%   	 (TP = 66, FP = 13)
# class_id = 5, name = chocolate, ap = 66.65%   	 (TP = 70, FP = 19)
# class_id = 6, name = coffee, ap = 85.83%   	 (TP = 121, FP = 20)
# class_id = 7, name = corn, ap = 88.03%   	 (TP = 46, FP = 11)
# class_id = 8, name = fish, ap = 83.29%   	 (TP = 51, FP = 15)
# class_id = 9, name = flour, ap = 85.85%   	 (TP = 35, FP = 9)
# ...
